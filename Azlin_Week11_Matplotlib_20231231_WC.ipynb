# %% [markdown]
# <a href="https://colab.research.google.com/github/AzlinRusnan/STQD6014-Data-Science/blob/main/Azlin_Week11_Matplotlib_20231231_WC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week 11: Plotting and Visualization using Matplotlib**
# please refer to the textbook: "Python for Data Analysis" by Wes McKinney for details of this topic (***Chapter 9***)

# %% [markdown]
# ## **Load library**

# %% [markdown]
# # ***This is like a template***

# %%
# load library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualisation purpose
import seaborn as sns # visualisation purpose

# %% [markdown]
# # **A quick glance on Matplotlib**
# - a 2D plotting library for Python that produces high-quality static plots

# %%
# Create some sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Plot the data
plt.plot(x,y)

# Add labels and title
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Simple plot'); # use semi-colon to suppress the output message

# %% [markdown]
# # **A quick glance on Seaborn**
# - built on top of Matplotlib
# - provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# # **Combination of Python function**
# **1. pandas**
#
# **2. seaborn**
#
# **3. matplotlib -> plt function**

# %%
# Create some sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a pandas DataFrame using the data
data = {'x': x, 'y': y} # this is a library
df = pd.DataFrame(data)
df

# Create a scatter plot using Seaborn
sns.scatterplot(x = 'x', y = 'y', data  = df)
# Add labels and title
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Seaborn Scatter plot');

# %% [markdown]
# # **Individual plots**

# %%
# Histogram - plot 1
# alpha=0.8: sets the transparency of the bars
# an alpha value of 0.8 means the bars are somewhat transparent
# normal distribution -> bell-shape curve
# standard normal -> mean = 0, sd = 1
rng = np.random.RandomState(12345)
plt.hist(rng.standard_normal(100), bins = 20, color = 'navy', alpha = .5) #final exam keluar tanya alpha

# Add labels and title
plt.xlabel('Standard Normal values')
plt.ylabel('Frequency')
plt.title('Matplotlib histogram');

# Save the plot in pdf format
plt.savefig("/content/drive/MyDrive/Colab_Notebooks/hist.pdf")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Scatter plot - plot 2
rng = np.random.RandomState(12345)
plt.scatter(x = np.arange(30), y = np.arange(30) + 5 * rng.standard_normal(30))
# Add labels and title
plt.xlabel('Values')
plt.ylabel('Standard Normal values')
plt.title('Matplotlib Scatterplot');

# %% [markdown]
# # **LINE PLOT IS SUITABLE FOR <font color = "red">TIME-RELATED INFORMATION**
# - **X- AXIS CAN NEVER BE A CATEGORICAL DATA**
# - Involved continuous data for x

# %%
# Line plot : plot 3
rng = np.random.RandomState(12345)
plt.plot(rng.standard_normal(50).cumsum(), color = 'red', linestyle = 'dashed', marker = 'o')

# Add label
plt.xlabel('DAYS')
plt.ylabel('y-axis')
plt.title('Matplotlib Line plot');

# %%
# To get help from our good old friend
plt.plot?

# %% [markdown]
# ### **Place all the subplots into one panel**
#
# 1.   **plt.figure()** - create a new figure
# 2.   **add_subplot** - to create one or more subplots
# 3. **dpi** -> Dots per inch

# %%
# create one or more subplots
# 2 x 2; 4 plots in total
rng = np.random.RandomState(12345)
fig = plt.figure(dpi=300) # this is to set the resolution of the figure

# Set up the subplot
ax1 = fig.add_subplot(2,2,1) #2x2
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# don't need the plt() function because we have already define in fig variable
ax1.hist(rng.standard_normal(100), bins = 20, color = 'navy', alpha = .5)
ax2.scatter(x = np.arange(30), y = np.arange(30) + 5 * rng.standard_normal(30))
ax3.plot(rng.standard_normal(50).cumsum(), color = 'red', linestyle = 'dashed', marker = 'o')

# How to save the figures
plt.savefig("/content/drive/MyDrive/Colab_Notebooks/combi_hist_scatter_line.pdf")

# %% [markdown]
# ### **Adjusting the spacing around subplots**

# %%
# An example that shrink the spacing of the subplots to zero
# change the value of wspace and hspace
# sharex=True parameter means that the subplots will share the same x-axis
# The "fig" variable is a reference to the entire figure
# The "axes" is a 2D array of subplot references
rng = np.random.RandomState(12345)
fig, axes = plt.subplots(2,2, sharex = True, sharey = False) # we have 2 x 2 sub plots

# The outer loop (for i in range(2)) iterates over rows
# The inner loop (for j in range(2)) iterates over columns
# Top left -> Top right -> bottom left -> bottom right
# (0, 0) = top left
# (0, 1) = top right
# (1, 0) = bottom left
# (1, 1) = bottom right
# Use for loop
for i in range(2):
    for j in range(2):
        axes[i,j].hist(rng.standard_normal(500), bins = 50, color = 'navy', alpha = .5)

# Adjust the space around the subplot
# wspace = width of the subplots
# hspace = height of the padding
fig.subplots_adjust(wspace = .5, hspace = .1)

# %%
# To find more information about the code
fig.subplots_adjust?

# %% [markdown]
# ### **Colors, Markers, and Line Styles**
#
# 1.   specify line styles using plt.plot documentation (***plt.plot?***)
# 2.   specify color using hexadecimal RGB code, e.g. ***"#CECECE"***
# 3. we can use a color picker tool on a website like ***https://www.colorhexa.com/*** to input the hexadecimal code and visualize the corresponding color

# %%
plt.plot?

# %%
# Adding markers on line plot
# hexadecimal RGB color code
rng = np.random.RandomState(12345)
plt.plot(rng.standard_normal(30).cumsum(), color = '#20b2aa', linestyle = ':', marker = "v");

# %%
# "?" is our best friend to find more information
#plt.plot?

# %%
# Adding legend label
rng = np.random.RandomState(12345)
dat = rng.standard_normal(30).cumsum()
plt.plot(dat, color = '#00bfff', linestyle = '--', label = 'Azlin')
plt.legend();

# %% [markdown]
# ### **Ticks, Labels, and Legends**
#
# 1.   parameter such as ***xlim([0, 10])*** sets the x-xis range from ***0 to 10***

# %% [markdown]
# ### ***Setting the title, axis labels, ticks, and tick labels***

# %%
# An example
rng = np.random.RandomState(12345)
fig, ax = plt.subplots()
ax.plot(rng.standard_normal(1000).cumsum())

# changex x-axis ticks annotation
ax.set_xticks([0,250,500,750,1000])
ax.set_xlabel('Time')
ax.set_ylabel('Values')
ax.set_title('My first Matplotlib - Line plot');

# %% [markdown]
# ### **Adding Legends**

# %%
# Plot
fig, ax = plt.subplots()
ax.plot(np.random.randn(1000).cumsum(), color = '#ff8c00', label = 'Malaysia')
ax.plot(np.random.randn(1000).cumsum(), color = '#1e90ff', label = 'Singapore')
ax.plot(np.random.randn(1000).cumsum(), color = '#556b2f', label = 'Thailand')

# Add the legend
ax.legend(title = 'Financial Crisis');
ax.set_xlabel('Days')
ax.set_ylabel('Values')
ax.set_title('Financial Crisis of different countries 2008');

# %% [markdown]
# # **Adding shapes to a plot**
# - <font color ="red">**Important for final exam**

# %%
# Adding shapes to a plot
# always use the code for creating subplots
fig, ax = plt.subplots()

# create a rectangle shape
# .4 -> width of the x axis
# .2 -> .75 + .2 = .95 -> height of the rectange
rect = plt.Rectangle((.2, .75), .4, .2, color = '#5f9ea0', alpha = .8)


# Create a circle shape
# .15 -> radius of the circle
circ = plt.Circle((.7, .2), .15, color = '#32cd32', alpha = .3) # (.7, .2) starting point

# Create a triangle shape
# hexagon - > polygon of 6 sides
trig = plt.Polygon([[.15, .15], [.35, .4], [.2, .6]], color = '#663399', alpha = .5)

# All all together
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(trig);

# %%
# Adding shapes to a plot : Attention
import matplotlib.patches as mpatches
fig, ax = plt.subplots()

rect = plt.Rectangle((.2, .75), .4, .2, color = '#5f9ea0', alpha = .8)
circ = plt.Circle((.7, .2), .15, color = '#32cd32', alpha = .3)
tri = plt.Polygon([[.15, .15], [.35, .4], [.2, .6]], color = '#663399', alpha = .5)

# Create a square shape
sqr = plt.Rectangle((.3,.1), .2, .2, color = '#c71585', alpha = .9)

# Create an ellipse shape
# (0.5, 0.5) -> This tuple specifies the center of the ellipse
# 0.2 -> width of the ellipse
# 0.1 -> height of the ellipse
ellipse = mpatches.Ellipse((.5,.5), .2,.1, color = '#00008b', )

# add hexagon
# 6 -> specify number of sides in the regular polygon
# 0.1 -> distance from the center of the circumcircle (the point at the center of the hexagon) to any of its vertices
hex = mpatches.RegularPolygon((.7,.8), 6, .1, color = '#ff4500') #6 edges

# Add all the subplot together
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(tri)
ax.add_patch(sqr)
ax.add_patch(ellipse)
ax.add_patch(hex);
# Out:
# <ipython-input-54-59de2f3f063c>:21: MatplotlibDeprecationWarning: Passing the radius parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   hex = mpatches.RegularPolygon((.7,.8), 6, .1, color = '#ff4500')

# %% [markdown]
# # **To know more about hexagon, please visit this site:** https://tinyurl.com/dfwma82t

# %% [markdown]
# ### **Saving Plots to File**
#
# 1. File format: "***.png***","***.pdf***","***.svg***","***.ps***","***.eps***", .etc
# 2. In any case, <font color = 'red'>"***please just use 'PDF'*** to ensure good resolution

# %%
# Save plots in high resolution
fig.savefig("/content/drive/MyDrive/Colab_Notebooks/Diff.pdf", dpi = 600)

# %% [markdown]
# ## **3rd Method: Plotting using pandas**

# %% [markdown]
# ### **Line plots**

# %%
s.plot?

# %%
# using series data -> i dimensional data
rng = np.random.RandomState(12345)
s = pd.Series(rng.standard_normal(10).cumsum(), index = np.arange(0,100,10))
s.plot();

# %%
# using Dataframe -> rows, and columns
rng = np.random.RandomState(12345)

df = pd.DataFrame(rng.standard_normal((10,4)).cumsum(0),
                  columns = ['A','B','C','D'],
                  index = np.arange(0,100,10))
print(df)
# Plot
df.plot();
# Out:
#            A         B         C         D
# 0  -0.204708  0.478943 -0.519439 -0.555730
# 10  1.761073  1.872349 -0.426531 -0.273984
# 20  2.530095  3.118784  0.580659 -1.570205
# 30  2.805087  3.347697  1.933575 -0.683776
# 40  0.803450  2.975854  3.602601 -1.122346
# 50  0.263708  3.452839  6.851545 -2.143573
# 60 -0.313379  3.576961  7.154158 -1.619801
# 70 -0.312439  4.920770  6.440614 -2.450955
# 80 -2.682670  3.060010  5.579857 -1.890809
# 90 -3.948605  3.179837  4.516344 -1.557927

# %%
# Display df content
df
# Out:
#            A         B         C         D
# 0  -0.204708  0.478943 -0.519439 -0.555730
# 10  1.761073  1.872349 -0.426531 -0.273984
# 20  2.530095  3.118784  0.580659 -1.570205
# 30  2.805087  3.347697  1.933575 -0.683776
# 40  0.803450  2.975854  3.602601 -1.122346
# 50  0.263708  3.452839  6.851545 -2.143573
# 60 -0.313379  3.576961  7.154158 -1.619801
# 70 -0.312439  4.920770  6.440614 -2.450955
# 80 -2.682670  3.060010  5.579857 -1.890809
# 90 -3.948605  3.179837  4.516344 -1.557927

# %% [markdown]
# ### **Bar plots**

# %%
# Series data
fig, ax = plt.subplots(2,1)
dat = pd.Series(np.random.uniform(size = 16), index = list('abcdefghijklmnop'))

# plot.bar is for plotting vertical bar
dat.plot.bar(ax = ax[0], color = '#5d8aa8', alpha = .5)
# plot.barh is for plotting horizontal bar
dat.plot.barh(ax = ax[1], color = '#ff69b4', alpha = .3);

# %%
# Pandas DataFrame
df = pd.DataFrame(np.random.uniform(size = (6, 4)),
                  index = ['one', 'two', 'three', 'four', 'five', 'six'],
                  columns =pd.Index(['A', 'B', 'C', 'D'], name = "Genus"))
df
# Out:
# Genus         A         B         C         D
# one    0.202711  0.702252  0.903275  0.724407
# two    0.027492  0.908324  0.894678  0.282290
# three  0.662552  0.022485  0.529942  0.234782
# four   0.445745  0.733632  0.545952  0.310280
# five   0.726780  0.107925  0.584218  0.215505
# six    0.545187  0.056068  0.304135  0.905734

# %%
# Create a bar plot
# grouped bar plot -> horizontal wise
df.plot.bar();

# %%
# Stacked bar plots
df.plot.barh(stacked = True, alpha = .5)
# Out:
# <Axes: >

# %% [markdown]
# # **Dealing with Data Frame: Important for final exam**

# %%
# A little project: dataset about restaurant tipping
# Download the tips data here: https://bit.ly/3jCROII
tips = pd.read_csv("https://bit.ly/3jCROII")
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
# Using the crosstab() function
# To compute a simple cross-tabulation of two (or more) factors.
# Create a two factors data frame
party_counts = pd.crosstab(tips['day'], tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
# Reindex the DataFrame to the desidered Day order
desired_order = ['Thur','Fri','Sat','Sun']
party_counts_ordered = party_counts.reindex(desired_order)
party_counts_ordered
# Out:
# size  1   2   3   4  5  6
# day
# Thur  1  48   4   5  1  3
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1

# %%
# Extract party_counts from col 2 to 5
# using loc method - explicit, using it as a label
# 2:5 is the column name; they are not integer in this case
party_counts_ordered_edit = party_counts_ordered.loc[:, 2:5] #2:5 is the column name
party_counts_ordered_edit
# Out:
# size   2   3   4  5
# day
# Thur  48   4   5  1
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3

# %%
# Normalize each row to sum of 1
# axis="index" argument indicates that the division should be done along the rows
# normalizing the values in each row of the DataFrame party_counts_edit
# by dividing them by the sum of values in the respective row
party_pcts = party_counts_ordered_edit.div(party_counts_ordered_edit.sum(axis = 1), axis = 'index')
party_pcts
# Out:
# size         2         3         4         5
# day
# Thur  0.827586  0.068966  0.086207  0.017241
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000

# %% [markdown]
# # **Using seaborn package**

# %%
# Display tips content
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# ..          ...   ...    ...   ...     ...   ...
# 239       29.03  5.92     No   Sat  Dinner     3
# 240       27.18  2.00    Yes   Sat  Dinner     2
# 241       22.67  2.00    Yes   Sat  Dinner     2
# 242       17.82  1.75     No   Sat  Dinner     2
# 243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
# Do some calculation
# Adding new column
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %%
# Create the horizontal bar plot with specified order
# black lines drawn on the bars represent the 70% confidence interval
sns.barplot(x = 'tip_pct', y = 'day', data = tips, orient = 'h', order = desired_order, errorbar=('ci', 70));

# %%
# Using hue() function -> to change into category label
# The "time" variable is used to differentiate different hues (colors) in the plot
sns.barplot(x = 'tip_pct', y = 'day', hue = 'time', data = tips, orient = 'h', order = desired_order);

# %% [markdown]
# ### **Histograms and Density Plots**
# discretized display of **value frequency**

# %%
# Display tips content
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %%
# histogram
tips['tip_pct'].plot.hist(bins = 50);

# %%
# density plot
tips['tip_pct'].plot.density();

# %% [markdown]
# ### **Scatter or Point Plots**
# examining the relationship between two one-dimensional data series

# %%
# Example dataset
# Download the dataset here: https://bit.ly/3FYxCYZ
# Go to this link if you want to know more about this data: http://tinyurl.com/mr3zy799
macro = pd.read_csv("https://bit.ly/3FYxCYZ")
macro
# Out:
#      year  quarter    realgdp  realcons   realinv  realgovt  realdpi      cpi  \
# 0    1959        1   2710.349    1707.4   286.898   470.045   1886.9   28.980
# 1    1959        2   2778.801    1733.7   310.859   481.301   1919.7   29.150
# 2    1959        3   2775.488    1751.8   289.226   491.260   1916.4   29.350
# 3    1959        4   2785.204    1753.7   299.356   484.052   1931.3   29.370
# 4    1960        1   2847.699    1770.5   331.722   462.199   1955.5   29.540
# ..    ...      ...        ...       ...       ...       ...      ...      ...
# 198  2008        3  13324.600    9267.7  1990.693   991.551   9838.3  216.889
# 199  2008        4  13141.920    9195.3  1857.661  1007.273   9920.4  212.174
# 200  2009        1  12925.410    9209.2  1558.494   996.287   9926.4  212.671
# 201  2009        2  12901.504    9189.0  1456.678  1023.528  10077.5  214.469
# 202  2009        3  12990.341    9256.0  1486.398  1044.088  10040.6  216.385
#
# ...

# %%
# Select a few variables
dat = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
dat
# Out:
#          cpi      m1  tbilrate  unemp
# 0     28.980   139.7      2.82    5.8
# 1     29.150   141.7      3.08    5.1
# 2     29.350   140.5      3.82    5.3
# 3     29.370   140.0      4.33    5.6
# 4     29.540   139.6      3.50    5.2
# ..       ...     ...       ...    ...
# 198  216.889  1474.7      1.17    6.0
# 199  212.174  1576.5      0.12    6.9
# 200  212.671  1592.8      0.22    8.1
# 201  214.469  1653.6      0.18    9.2
# 202  216.385  1673.9      0.12    9.6
#
# [203 rows x 4 columns]

# %%
# Need to do normalisation; standardized the data
# Log transform the data
# diff() -> calculates the difference between that element and the previous one
trans_dat = np.log(dat).diff().dropna()
trans_dat
# Out:
#           cpi        m1  tbilrate     unemp
# 1    0.005849  0.014215  0.088193 -0.128617
# 2    0.006838 -0.008505  0.215321  0.038466
# 3    0.000681 -0.003565  0.125317  0.055060
# 4    0.005772 -0.002861 -0.212805 -0.074108
# 5    0.000338  0.004289 -0.266946  0.000000
# ..        ...       ...       ...       ...
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560
#
# [202 rows x 4 columns]

# %%
# Further explanation
np.log(29.150)-np.log(28.980)
# Out:
# 0.005848975903965048

# %%
# Plot the regression plot
fig = sns.regplot(x = 'm1', y = 'unemp', data = trans_dat)
fig.set(title = 'Changes in log(m1) versus log(unemp)');

# %%
# scatter plot matrix
# kde = kernel density estimate - another name for density plot
# estimate of the continuous probability distribution
# diag_kind="kde" -> specifies the type of plot to be used along the diagonal
# plot_kws() -> pass additional keyword arguments to the plotting function

sns.pairplot(trans_dat, diag_kind = 'kde', plot_kws = {'alpha' : 0.2});

# %% [markdown]
# ### **Facet Grids and Categorical Data**
# visualize data with many ***categorical variables***
#
# Seaborn **catplot** function simplifies making many kinds of faceted plots split by ***categorical variables***
#
# ***faceted*** means having many sides

# %%
# Displaying the tips data frame
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.063204
# 1         10.34  1.66     No   Sun  Dinner     3  0.191244
# 2         21.01  3.50     No   Sun  Dinner     3  0.199886
# 3         23.68  3.31     No   Sun  Dinner     2  0.162494
# 4         24.59  3.61     No   Sun  Dinner     4  0.172069
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.256166
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.079428
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.096759
# 242       17.82  1.75     No   Sat  Dinner     2  0.108899
# 243       18.78  3.00     No  Thur  Dinner     2  0.190114
#
# [244 rows x 7 columns]

# %%
# Categorical plot
# columns -> smoker
sns.catplot(x = 'day', y = 'tip_pct', hue = 'time', col = 'smoker',
           kind = 'bar', data = tips[tips.tip_pct < 1], order = desired_order);

# %%
# More examples: bar plot
sns.catplot(x = 'day', y = 'tip_pct', row = 'time', col = 'smoker',
            kind = 'bar', data = tips[tips.tip_pct < 1], order = desired_order);

# %%
# Box plot
sns.catplot(x = 'tip_pct', y = 'day', kind = 'box',
            data = tips[tips.tip_pct < 0.5], order = desired_order);

# %% [markdown]
# # **Before we go, a complex graph to end the day**

# %%
# Importing the datetime module
from datetime import datetime

# Create a figure and an axis
fig, ax = plt.subplots()

# Download the closing S&P 500 index price: 1990-02-01 until 2011-10-14
# The link: https://bit.ly/3iofIY8
data = pd.read_csv("https://bit.ly/3iofIY8", index_col=0, parse_dates=True)

# Extract the SPX data
spx = data["SPX"]

# Plot the SPX data from 1990 until 2011
spx.plot(ax=ax, color="blue")

# 2008–2009 financial crisis
crisis_data = [
    (datetime(2007, 10, 11), "Peak of bull market"),
    (datetime(2008, 3, 12), "Bear Stearns Fails"),
    (datetime(2008, 9, 15), "Lehman Bankruptcy")
]

# Using Matplotlib's annotate method to add annotations
for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75), # Coordinate of the points
                xytext=(date, spx.asof(date) + 225), # Coordinate of the labels
                arrowprops=dict(facecolor="black", headwidth=4, width=2, headlength=4), # A dictionary specifying arrow properties
                horizontalalignment="left",
                verticalalignment="top")

# Zoom in on 2007-2010
ax.set_xlim(["1/1/2007", "1/1/2011"])
ax.set_ylim([600, 1800])

ax.set_title("Important dates in the 2008–2009 financial crisis");

# %% [markdown]
# # **That's it for the day!!! :)**
# # **Wishing everyone Happy New Year!!! :)**

# %% [markdown]
# ![Screenshot 2023-12-27 at 8.33.08 AM.png](data:image/png;base64,...)
